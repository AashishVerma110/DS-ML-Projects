# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
# Unnamed: 0          1303 non-null int64
# Company             1303 non-null object
# TypeName            1303 non-null object
# Inches              1303 non-null float64
# ScreenResolution    1303 non-null object
# Cpu                 1303 non-null object
# Ram                 1303 non-null object
# Memory              1303 non-null object
# Gpu                 1303 non-null object
# OpSys               1303 non-null object
# Weight              1303 non-null object
# Price               1303 non-null float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 76.4+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
# Company             1303 non-null object
# TypeName            1303 non-null object
# Inches              1303 non-null float64
# ScreenResolution    1303 non-null object
# Cpu                 1303 non-null object
# Ram                 1303 non-null int32
# Memory              1303 non-null object
# Gpu                 1303 non-null object
# OpSys               1303 non-null object
# Weight              1303 non-null float32
# Price               1303 non-null float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 66.2+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])

# %%
df['Company'].value_counts().plot(kind='bar')

# %%
sns.barplot(df['Company'],df['Price'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['TypeName'].value_counts().plot(kind='bar')

# %%
sns.barplot(df['TypeName'],df['Price'],)
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.distplot(df['Inches'])

# %%
sns.scatterplot(x= df['Inches'], y=df['Price'])

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2256x1504                              6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 2560x1440                       3
# 1920x1080                                          3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 2560x1440                                          3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Touchscreen 2400x1600                    1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Retina Display 2736x1824                 1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / 4K Ultra HD 3840x2160                1
# Touchscreen / Full HD 1920x1080                    1
# Name: ScreenResolution, dtype: int64

# %%
df['TouchScreen']= df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(10)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 157     Asus  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 904   Lenovo            Notebook    15.6      IPS Panel Full HD 1920x1080
# 926   Lenovo           Ultrabook    12.5      IPS Panel Full HD 1920x1080
# 1268      HP             Netbook    11.6                         1366x768
# 935       HP             Netbook    12.5                Full HD 1920x1080
# 727     Dell  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 32        HP            Notebook    17.3                Full HD 1920x1080
# 202     Acer            Notebook    15.6                Full HD 1920x1080
# 856     Asus            Notebook    15.6                         1366x768
# 1053      HP            Notebook    15.6                         1366x768
#
#                                        Cpu  Ram              Memory  \
# 157             Intel Core i5 8250U 1.6GHz    8           256GB SSD
# 904             Intel Core i5 7200U 2.5GHz    8           512GB SSD
# 926             Intel Core i7 7500U 2.7GHz    8           256GB SSD
# 1268  Intel Celeron Dual Core N3060 1.6GHz    2  32GB Flash Storage
# 935             Intel Core i5 6200U 2.3GHz    8           256GB SSD
# 727             Intel Core i3 7100U 2.4GHz    4             1TB HDD
# 32               AMD A6-Series 9220 2.5GHz    4           500GB HDD
# 202             Intel Core i7 7500U 2.7GHz    8             1TB HDD
# 856   Intel Pentium Quad Core N4200 1.1GHz    4             1TB HDD
# 1053            Intel Core i5 7200U 2.5GHz    4           256GB SSD
#
#                         Gpu       OpSys  Weight        Price  TouchScreen
# 157   Intel HD Graphics 620  Windows 10    1.10   70063.2000            1
# 904   Intel HD Graphics 620  Windows 10    1.95  104588.1072            0
# 926   Intel HD Graphics 620  Windows 10    1.36   87912.0000            0
# 1268  Intel HD Graphics 400  Windows 10    1.17   11135.5200            0
# 935   Intel HD Graphics 520  Windows 10    1.26   88924.3200            0
# 727   Intel HD Graphics 620  Windows 10    1.71   34578.7200            1
# 32           AMD Radeon 530  Windows 10    2.71   23389.9200            0
# 202    Nvidia GeForce 940MX  Windows 10    2.23   39533.7600            0
# 856   Intel HD Graphics 505  Windows 10    2.00   23922.7200            0
# 1053  Intel HD Graphics 620  Windows 10    2.04   52161.1200            0

# %%
df['TouchScreen'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df["TouchScreen"], y=df['Price'])

# %%
df['Ips'] =df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
sns.barplot(x=df["Ips"], y=df['Price'])

# %%
new= df['ScreenResolution'].str.split('x',n=1, expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(10)
# Out:
#       Company            TypeName  Inches  \
# 706      Acer  2 in 1 Convertible    13.3
# 1289     Asus           Ultrabook    13.3
# 175      Dell            Notebook    15.6
# 620        HP            Notebook    14.0
# 952   Toshiba            Notebook    13.3
# 1041     Vero            Notebook    14.0
# 49       Asus            Notebook    17.3
# 645    Lenovo            Notebook    14.0
# 726      Dell            Notebook    15.6
# 1056       HP            Notebook    15.6
#
#                                ScreenResolution  \
# 706   IPS Panel Full HD / Touchscreen 1920x1080
# 1289                IPS Panel Full HD 1920x1080
# 175                                    1366x768
# 620                                    1366x768
# 952                           Full HD 1920x1080
# 1041                                   1366x768
# 49                                     1366x768
# 645                                    1366x768
# 726                           Full HD 1920x1080
# 1056                                   1366x768
#
#                                        Cpu  Ram                Memory  \
# 706             Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 1289              Intel Core M 6Y30 0.9GHz    8             512GB SSD
# 175             Intel Core i3 7100U 2.4GHz    8               1TB HDD
# 620             Intel Core i5 7300U 2.6GHz    8             256GB SSD
# 952             Intel Core i5 6200U 2.3GHz    8             256GB SSD
# 1041           Intel Atom X5-Z8350 1.44GHz    2    32GB Flash Storage
# 49    Intel Pentium Quad Core N4200 1.1GHz    4               1TB HDD
# 645   Intel Celeron Dual Core N3060 1.6GHz    4    32GB Flash Storage
# 726             Intel Core i5 8250U 1.6GHz    8  128GB SSD +  1TB HDD
# 1056            Intel Core i5 7200U 2.5GHz    4             500GB HDD
#
#                          Gpu       OpSys  Weight      Price  TouchScreen  Ips  \
# 706   Intel UHD Graphics 620  Windows 10    1.60  53226.720            1    1
# 1289   Intel HD Graphics 515  Windows 10    1.20  38841.120            0    1
# 175    Intel HD Graphics 620  Windows 10    2.30  24455.520            0    0
# 620    Intel HD Graphics 620  Windows 10    2.31  59886.720            0    0
# 952    Intel HD Graphics 520   Windows 7    1.20  77788.800            0    0
# 1041   Intel HD Graphics 400  Windows 10    1.45  11231.424            0    0
# 49      Nvidia GeForce 920MX  Windows 10    2.80  24828.480            0    0
# 645        Intel HD Graphics  Windows 10    1.43  14598.720            0    0
# 726           AMD Radeon 530  Windows 10    2.20  38308.320            0    0
# 1056   Intel HD Graphics 620       No OS    1.96  26586.720            0    0
#
#                                      X_res Y_res
# 706   IPS Panel Full HD / Touchscreen 1920  1080
# 1289                IPS Panel Full HD 1920  1080
# 175                                   1366   768
# 620                                   1366   768
# 952                           Full HD 1920  1080
# 1041                                  1366   768
# 49                                    1366   768
# 645                                   1366   768
# 726                           Full HD 1920  1080
# 1056                                  1366   768

# %%
# use of regular expression for X_res column
df['X_res'] = df['X_res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0] )

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res
# 0   2560   1600
# 1   1440    900
# 2   1920   1080
# 3   2880   1800
# 4   2560   1600

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
# determining the Pixel Per Inches which is calculated as ((x_res^2 + y_res^2)^0.5)/inches
df['PPI'] = ((df["X_res"]**2+df["Y_res"]**2)**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
#df.drop(columns=['ScreenResolution'])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res         PPI
# 0   2560   1600  226.983005
# 1   1440    900  127.677940
# 2   1920   1080  141.211998
# 3   2880   1800  220.534624
# 4   2560   1600  226.983005

# %%
df.drop(columns=['Inches','X_res','Y_res'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df["Cpu"].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz               190
# Intel Core i7 7700HQ 2.8GHz              146
# Intel Core i7 7500U 2.7GHz               134
# Intel Core i7 8550U 1.8GHz                73
# Intel Core i5 8250U 1.6GHz                72
# Intel Core i5 6200U 2.3GHz                68
# Intel Core i3 6006U 2GHz                  64
# Intel Core i7 6500U 2.5GHz                49
# Intel Core i7 6700HQ 2.6GHz               43
# Intel Core i3 7100U 2.4GHz                37
# Intel Core i5 7300HQ 2.5GHz               33
# Intel Celeron Dual Core N3350 1.1GHz      30
# Intel Celeron Dual Core N3060 1.6GHz      28
# Intel Core i7 6600U 2.6GHz                18
# Intel Core i3 6006U 2.0GHz                16
# Intel Pentium Quad Core N4200 1.1GHz      14
# Intel Core i5 7300U 2.6GHz                14
# Intel Core i7 7600U 2.8GHz                13
# Intel Celeron Dual Core N3050 1.6GHz      11
# AMD A9-Series 9420 3GHz                   11
# Intel Pentium Quad Core N3710 1.6GHz      11
# Intel Core i5 6300U 2.4GHz                11
# Intel Core i7 6820HK 2.7GHz               10
# Intel Core i3 6100U 2.3GHz                 9
# Intel Core i3 7130U 2.7GHz                 8
# AMD A6-Series 9220 2.5GHz                  7
# Intel Core i7 7820HK 2.9GHz                7
# Intel Core i5 6300HQ 2.3GHz                7
# Intel Core i7 6820HQ 2.7GHz                7
# Intel Core i7 7Y75 1.3GHz                  5
#                                         ...
# Intel Atom Z8350 1.92GHz                   1
# AMD Ryzen 1600 3.2GHz                      1
# Intel Core M M7-6Y75 1.2GHz                1
# Intel Celeron Dual Core N3060 1.60GHz      1
# Intel Core i7 6920HQ 2.9GHz                1
# AMD E-Series 9000e 1.5GHz                  1
# Intel Core i5 2.9GHz                       1
# Intel Core i7 2.7GHz                       1
# Intel Core i7 2.9GHz                       1
# AMD A6-Series 7310 2GHz                    1
# Intel Atom x5-Z8300 1.44GHz                1
# AMD A12-Series 9700P 2.5GHz                1
# Intel Core i3 6100U 2.1GHz                 1
# AMD FX 9830P 3GHz                          1
# Intel Core M 7Y30 1.0GHz                   1
# Intel Core i7 2.2GHz                       1
# Intel Core i5 7200U 2.50GHz                1
# AMD A6-Series 9220 2.9GHz                  1
# Intel Core i5 1.3GHz                       1
# Intel Core i5 6440HQ 2.6GHz                1
# Intel Core M m7-6Y75 1.2GHz                1
# Intel Core i5 7200U 2.70GHz                1
# AMD FX 8800P 2.1GHz                        1
# Intel Core i7 7700HQ 2.7GHz                1
# Intel Core i5 2.0GHz                       1
# Intel Core M m3 1.2GHz                     1
# AMD A4-Series 7210 2.2GHz                  1
# Intel Core M m3-7Y30 2.2GHz                1
# Intel Core M M3-6Y30 0.9GHz                1
# Intel Core M 6Y54 1.1GHz                   1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['CPU Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text =='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['CPU Brand'] = df['CPU Name'].apply(fetch_processor)

# %%
df.sample(10)
# Out:
#      Company            TypeName                 ScreenResolution  \
# 1224    Dell  2 in 1 Convertible  Full HD / Touchscreen 1920x1080
# 650     Asus              Gaming      IPS Panel Full HD 1920x1080
# 188     Acer           Ultrabook      IPS Panel Full HD 1920x1080
# 1160  Lenovo           Ultrabook                Full HD 1920x1080
# 461     Acer             Netbook                         1366x768
# 1187    Acer            Notebook                Full HD 1920x1080
# 139       HP            Notebook      IPS Panel Full HD 1920x1080
# 712     Dell            Notebook                Full HD 1920x1080
# 199       HP            Notebook                Full HD 1920x1080
# 160     Asus            Notebook                         1366x768
#
#                                        Cpu  Ram     Memory  \
# 1224            Intel Core i3 7100U 2.4GHz    4  500GB HDD
# 650            Intel Core i7 6820HK 2.7GHz   32  512GB SSD
# 188              Intel Core i5 7Y54 1.2GHz    8  256GB SSD
# 1160            Intel Core i7 6600U 2.6GHz    8  256GB SSD
# 461   Intel Celeron Dual Core N3060 1.6GHz    4  128GB SSD
# 1187            Intel Core i5 7200U 2.5GHz    4  256GB SSD
# 139             Intel Core i5 7200U 2.5GHz    4  256GB SSD
# 712             Intel Core i5 7200U 2.5GHz    8    1TB HDD
# 199             Intel Core i7 8550U 1.8GHz    8  256GB SSD
# 160                AMD A9-Series 9420 3GHz    4    1TB HDD
#
#                           Gpu       OpSys  Weight      Price  TouchScreen  \
# 1224    Intel HD Graphics 620  Windows 10    2.08   27119.52            1
# 650   Nvidia GeForce GTX 1080  Windows 10    3.80  149130.72            0
# 188     Intel HD Graphics 615  Windows 10    1.12   52693.92            0
# 1160    Intel HD Graphics 520   Windows 7    1.70   79866.72            0
# 461     Intel HD Graphics 400  Windows 10    1.40   23176.80            0
# 1187     Nvidia GeForce 940MX  Windows 10    2.23   36816.48            0
# 139     Intel HD Graphics 620  Windows 10    1.32   37242.72            0
# 712     Intel HD Graphics 620       Linux    1.98   38681.28            0
# 199     Nvidia GeForce 930MX   Windows 10    2.50   55677.60            0
# 160        AMD Radeon R5 M420  Windows 10    2.03   21471.84            0
#
#       Ips         PPI            CPU Name              CPU Brand
# 1224    0  146.860478       Intel Core i3          Intel Core i3
# 650     1  127.335675       Intel Core i7          Intel Core i7
# 188     1  165.632118       Intel Core i5          Intel Core i5
# 1160    0  157.350512       Intel Core i7          Intel Core i7
# 461     0  135.094211  Intel Celeron Dual  Other Intel Processor
# 1187    0  141.211998       Intel Core i5          Intel Core i5
# 139     1  165.632118       Intel Core i5          Intel Core i5
# 712     0  141.211998       Intel Core i5          Intel Core i5
# 199     0  127.335675       Intel Core i7          Intel Core i7
# 160     0  100.454670  AMD A9-Series 9420          AMD Processor

# %%
df['CPU Brand'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['CPU Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns =['Cpu', 'CPU Name','ScreenResolution'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  Ips         PPI      CPU Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Ram'], y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 512GB Flash Storage                2
# 256GB SSD +  500GB HDD             2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 32GB HDD                           1
# 8GB SSD                            1
# 256GB SSD +  1.0TB Hybrid          1
# 1.0TB HDD                          1
# 508GB Hybrid                       1
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  1.0TB Hybrid          1
# 240GB SSD                          1
# 1TB HDD +  1TB HDD                 1
# 64GB SSD                           1
# 64GB Flash Storage +  1TB HDD      1
# 128GB HDD                          1
# Name: Memory, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)


df["first"]= new[0]
df["first"]=df["first"].str.strip()


df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)


df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(10)
# Out:
#       Company  TypeName  Ram               Memory                      Gpu  \
# 76     Lenovo  Notebook    8             2000 HDD    Intel HD Graphics 620
# 760    Lenovo    Gaming    8  128 SSD +  1000 HDD  Nvidia GeForce GTX 1050
# 668   Toshiba  Notebook    8              256 SSD    Intel HD Graphics 620
# 91       Acer  Notebook    8             1000 HDD     Nvidia GeForce MX150
# 593   Samsung  Notebook   16  128 SSD +  1000 HDD  Nvidia GeForce GTX 1050
# 1273       HP  Notebook    6             1000 HDD       AMD Radeon R5 M330
# 440    Lenovo  Notebook    8             1000 HDD            AMD Radeon R4
# 1264     Dell  Notebook    2              500 HDD        Intel HD Graphics
# 13       Dell  Notebook    4              256 SSD       AMD Radeon R5 M430
# 211      Asus    Gaming   16  256 SSD +  1000 HDD  Nvidia GeForce GTX 1050
#
#            OpSys  Weight      Price  TouchScreen  Ips         PPI  \
# 76         No OS    2.20  27652.320            0    0  141.211998
# 760   Windows 10    2.50  55837.440            0    1  141.211998
# 668   Windows 10    2.00  67026.240            0    1  141.211998
# 91    Windows 10    2.20  36709.920            0    0  141.211998
# 593   Windows 10    2.50  90522.720            0    0  141.211998
# 1273  Windows 10    2.19  40705.920            0    0  100.454670
# 440   Windows 10    2.80  27652.320            0    0  106.113062
# 1264  Windows 10    2.20  20193.120            0    0  100.454670
# 13    Windows 10    2.20  26581.392            0    0  141.211998
# 211   Windows 10    2.90  74964.960            0    0  127.335675
#
#                   CPU Brand   HDD  SSD  Hybrid  Flash_Storage
# 76            Intel Core i5  2000    0       0              0
# 760           Intel Core i7  1000  128       0              0
# 668           Intel Core i5     0  256       0              0
# 91            Intel Core i7  1000    0       0              0
# 593           Intel Core i7  1000  128       0              0
# 1273          Intel Core i7  1000    0       0              0
# 440           AMD Processor  1000    0       0              0
# 1264  Other Intel Processor   500    0       0              0
# 13            Intel Core i3     0  256       0              0
# 211           Intel Core i7  1000  256       0              0

# %%
df.drop(columns=['Memory'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips         PPI      CPU Brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.corr()["Price"]
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# Ips              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips         PPI      CPU Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620           281
# Intel HD Graphics 520           185
# Intel UHD Graphics 620           68
# Nvidia GeForce GTX 1050          66
# Nvidia GeForce GTX 1060          48
# Nvidia GeForce 940MX             43
# AMD Radeon 530                   41
# Intel HD Graphics 500            39
# Intel HD Graphics 400            37
# Nvidia GeForce GTX 1070          30
# Intel HD Graphics                29
# Nvidia GeForce GTX 1050 Ti       28
# AMD Radeon R5 M430               22
# Nvidia GeForce 930MX             20
# AMD Radeon 520                   17
# Nvidia GeForce MX150             15
# Intel HD Graphics 515            15
# Nvidia GeForce GTX 960M          14
# Intel HD Graphics 615            14
# AMD Radeon R7 M445               14
# Nvidia GeForce 920MX             13
# Intel HD Graphics 505            12
# AMD Radeon R5                    11
# Nvidia GeForce GTX 980M          10
# Intel HD Graphics 405             9
# Nvidia Quadro M1200               9
# AMD Radeon R5 M420                8
# Intel Iris Plus Graphics 640      8
# AMD Radeon R5 M330                7
# Nvidia GeForce GTX 950M           7
#                                ...
# AMD FirePro W5130M                1
# AMD Radeon RX 560                 1
# Nvidia Quadro M3000M              1
# AMD R17M-M1-70                    1
# Intel HD Graphics 540             1
# AMD Radeon R5 430                 1
# AMD Radeon R7 M365X               1
# Nvidia GeForce GTX1060            1
# AMD Radeon Pro 455                1
# AMD Radeon R5 520                 1
# Intel HD Graphics 530             1
# Intel Iris Pro Graphics           1
# Nvidia Quadro M620M               1
# AMD FirePro W4190M                1
# AMD Radeon 540                    1
# AMD Radeon R3                     1
# AMD Radeon Pro 560                1
# Intel Graphics 620                1
# Nvidia GeForce 940M               1
# Intel HD Graphics 620             1
# AMD Radeon R7 Graphics            1
# Intel Iris Graphics 550           1
# AMD Radeon R7                     1
# Nvidia GeForce GTX 940M           1
# AMD FirePro W6150M                1
# ARM Mali T860 MP4                 1
# Nvidia GeForce GTX 930MX          1
# AMD Radeon R7 M360                1
# Nvidia GeForce GTX 1070M          1
# Nvidia GeForce GTX 980            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['GPU Brand']= df['Gpu'].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips         PPI      CPU Brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   GPU Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['GPU Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GPU Brand, dtype: int64

# %%
# remove the row having ARM as GPU Brand

df = df[df['GPU Brand']!='ARM']

# %%
df['GPU Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: GPU Brand, dtype: int64

# %%
# checkinig the dependency of GPU Brand wiht price

sns.barplot(x= df['GPU Brand'], y= df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(columns=['Gpu'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      CPU Brand  HDD  SSD GPU Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x =df['OpSys'], y= df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(os):
    if os =='Windows 10 ' or os=='Windows 7' or os=='Windows 10 S':
        return "Windows"
    elif os == 'macOS' or os=='Mac OS X':
        return "Mac"
    else:
        return 'Others/No OS/Linux'

# %%
df['OS']=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  TouchScreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      CPU Brand  HDD  SSD GPU Brand                  OS
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  TouchScreen  Ips         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        CPU Brand  HDD  SSD GPU Brand                  OS
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.barplot(x =df['OS'], y= df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])

# %%
sns.scatterplot(x=df['Weight'], y=df['Price'])

# %%
sns.heatmap(df.corr())

# %%
'''since our target column i.e 'Price' is somewhat skewed, that could hamper the 
performance of our model
So, we need to transform the Price column'''

sns.distplot(df['Price'])

# %%
sns.distplot(np.log(df['Price']))

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
# 5        9.967026
# 6       11.644108
# 7       11.030615
# 8       11.285443
# 9       10.621952
# 10       9.951658
# 11       9.819076
# 12      11.775302
# 13      10.187967
# 14      11.116331
# 15      11.301072
# 16      10.588945
# 17      11.933438
# 18      10.188167
# 19      10.862093
# 20       9.232535
# 21      10.882316
# 22       9.528521
# 23      10.683645
# 24      10.466285
# 25      10.012572
# 26      10.977717
# 27      10.660173
# 28      11.144141
# 29      10.773501
#           ...
# 1273    10.614129
# 1274     9.886358
# 1275    10.567235
# 1276    10.104611
# 1277     9.641988
# 1278     9.913097
# 1279    10.776844
# 1280    10.285461
# 1281    10.667632
# 1282     9.317895
# 1283    10.555257
# 1284    10.433899
# 1285    11.288115
# 1286     9.409283
# 1287    10.614129
# 1288     9.886358
# 1289    10.567235
# 1290    10.104611
# 1291     9.641988
# 1292     9.913097
# 1293    10.776844
# 1294    10.285461
# 1295    10.667632
# 1296     9.317895
# 1297    10.555257
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.15, random_state = 2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  TouchScreen  Ips         PPI  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# 1066     Asus              Gaming   64    3.58            0    1  127.335675
# 315      Dell            Notebook    8    2.33            0    0  141.211998
# 1003       HP            Notebook    4    1.64            0    0  111.935204
# 119      Asus            Notebook    8    1.70            0    0  141.211998
# 367    Lenovo              Gaming    8    2.40            0    1  141.211998
# 511      Acer            Notebook    4    2.20            0    0  141.211998
# 436        HP            Notebook    4    2.10            0    0  100.454670
# 1043   Lenovo            Notebook    8    2.30            0    0  141.211998
# 1158   Lenovo            Notebook    8    2.50            0    0  141.211998
# 619      Acer  2 in 1 Convertible    4    1.25            1    1  135.094211
# 823       MSI              Gaming    8    2.40            0    0  141.211998
# 905        LG           Ultrabook   16    1.08            1    1  141.211998
# 1148       HP            Notebook    8    1.88            0    0  141.211998
# 487      Dell            Notebook   16    2.06            0    0  141.211998
# 21     Lenovo              Gaming    8    2.50            0    1  141.211998
# 1104   Lenovo              Gaming   16    2.40            0    0  141.211998
# 286    Lenovo            Notebook    8    1.95            0    1  141.211998
# 201    Lenovo            Notebook    4    2.10            0    0  100.454670
# 931        HP           Ultrabook    4    1.26            0    0  176.232574
# 397    Lenovo            Notebook    8    1.90            0    1  157.350512
# 268        HP            Notebook    8    2.50            0    0  127.335675
# 1012       HP            Notebook    4    1.48            0    0  157.350512
# 301      Asus              Gaming   16    2.90            0    0  127.335675
# 973   Toshiba            Notebook    8    1.95            0    0  157.350512
# 45      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...       ...                 ...  ...     ...          ...  ...         ...
# 1112   Lenovo            Notebook    4    2.10            0    0  100.454670
# 255      Dell           Ultrabook    8    1.41            0    0  165.632118
# 892   Samsung           Ultrabook    8    1.17            0    0  146.860478
# 359      Dell            Notebook    8    1.36            0    0  157.350512
# 51       Acer            Notebook    8    2.20            0    1  141.211998
# 875      Dell           Ultrabook    8    1.60            0    0  176.232574
# 938      Dell           Ultrabook    8    1.36            0    0  157.350512
# 772   Toshiba            Notebook    4    1.75            0    1  111.935204
# 1126   Lenovo  2 in 1 Convertible    4    0.69            1    1  224.173809
# 1220   Lenovo            Notebook    8    2.30            0    1  141.211998
# 679      Acer              Gaming   16    2.50            0    0  141.211998
# 805        HP             Netbook    8    1.26            0    0  125.367428
# 124      Acer            Notebook    4    2.10            0    0  100.454670
# 404       MSI              Gaming   16    2.80            0    0  127.335675
# 730      Acer              Gaming   16    4.20            0    1  127.335675
# 831    Lenovo           Ultrabook   16    1.10            0    1  209.800683
# 1071       HP            Notebook    4    2.31            0    0  100.454670
# 725    Lenovo            Notebook    4    1.90            0    0  100.454670
# 587    Lenovo           Ultrabook   12    1.40            0    1  157.350512
# 607    Lenovo            Notebook    6    2.40            0    0  141.211998
# 433    Lenovo         Workstation   16    2.30            0    1  282.423996
# 674        HP  2 in 1 Convertible    4    1.63            1    1  157.350512
# 1288     Asus            Notebook    4    2.20            0    0  100.454670
# 360        HP            Notebook    4    1.86            0    0  100.454670
# 1099     Asus              Gaming   16    4.30            0    1  127.335675
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   CPU Brand   HDD   SSD GPU Brand                  OS
# 183           Intel Core i5     0   128     Intel  Others/No OS/Linux
# 1141          Intel Core i7  1000   128    Nvidia  Others/No OS/Linux
# 1049  Other Intel Processor     0     0     Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000     0     Intel  Others/No OS/Linux
# 878           Intel Core i5  1000   128    Nvidia  Others/No OS/Linux
# 1066          Intel Core i7     0  1000    Nvidia  Others/No OS/Linux
# 315           Intel Core i5  1000   128       AMD  Others/No OS/Linux
# 1003          Intel Core i5   500     0     Intel  Others/No OS/Linux
# 119           Intel Core i7     0   256    Nvidia  Others/No OS/Linux
# 367           Intel Core i5  1000   128    Nvidia  Others/No OS/Linux
# 511           Intel Core i7   500     0    Nvidia  Others/No OS/Linux
# 436   Other Intel Processor   500     0     Intel  Others/No OS/Linux
# 1043          Intel Core i5     0   256     Intel  Others/No OS/Linux
# 1158          Intel Core i5     0     0       AMD  Others/No OS/Linux
# 619   Other Intel Processor     0     0     Intel  Others/No OS/Linux
# 823           Intel Core i5     0   256    Nvidia  Others/No OS/Linux
# 905           Intel Core i7     0   512     Intel  Others/No OS/Linux
# 1148          Intel Core i5     0   256     Intel             Windows
# 487           Intel Core i7     0   512    Nvidia  Others/No OS/Linux
# 21            Intel Core i5  1000   128    Nvidia  Others/No OS/Linux
# 1104          Intel Core i7     0   512    Nvidia  Others/No OS/Linux
# 286           Intel Core i7     0   256     Intel  Others/No OS/Linux
# 201           Intel Core i5     0   128     Intel  Others/No OS/Linux
# 931           Intel Core i5   500     0     Intel  Others/No OS/Linux
# 397           Intel Core i5     0   256     Intel  Others/No OS/Linux
# 268           Intel Core i7  1000     0    Nvidia  Others/No OS/Linux
# 1012          Intel Core i5     0   256     Intel  Others/No OS/Linux
# 301           Intel Core i7  1000   256    Nvidia  Others/No OS/Linux
# 973           Intel Core i5     0   256     Intel  Others/No OS/Linux
# 45            Intel Core i5     0   256     Intel                 Mac
# ...                     ...   ...   ...       ...                 ...
# 1112          Intel Core i3     0   128     Intel  Others/No OS/Linux
# 255           Intel Core i5     0   256     Intel  Others/No OS/Linux
# 892           Intel Core i7     0   256     Intel  Others/No OS/Linux
# 359           Intel Core i5     0   256     Intel  Others/No OS/Linux
# 51            Intel Core i7     0   256    Nvidia  Others/No OS/Linux
# 875           Intel Core i7     0   256     Intel  Others/No OS/Linux
# 938           Intel Core i5     0   256     Intel  Others/No OS/Linux
# 772           Intel Core i5     0   128     Intel  Others/No OS/Linux
# 1126  Other Intel Processor     0     0     Intel  Others/No OS/Linux
# 1220          Intel Core i7     0   256     Intel  Others/No OS/Linux
# 679           Intel Core i5     0   256    Nvidia  Others/No OS/Linux
# 805           Intel Core i5     0   256     Intel  Others/No OS/Linux
# 124           AMD Processor     0   256       AMD  Others/No OS/Linux
# 404           Intel Core i7  1000   256    Nvidia  Others/No OS/Linux
# 730           Intel Core i7  1000   128    Nvidia  Others/No OS/Linux
# 831           Intel Core i7     0   512     Intel  Others/No OS/Linux
# 1071          Intel Core i5   500     0     Intel  Others/No OS/Linux
# 725           Intel Core i5  1000     0     Intel  Others/No OS/Linux
# 587           Intel Core i7     0   256     Intel  Others/No OS/Linux
# 607           Intel Core i5  1000     0     Intel  Others/No OS/Linux
# 433           Intel Core i7     0   512    Nvidia  Others/No OS/Linux
# 674           Intel Core i3     0   128    Nvidia  Others/No OS/Linux
# 1288  Other Intel Processor   500     0     Intel  Others/No OS/Linux
# 360           Intel Core i3   500     0     Intel  Others/No OS/Linux
# 1099          Intel Core i7  1000   128    Nvidia  Others/No OS/Linux
# 466           Intel Core i3   500     0    Nvidia  Others/No OS/Linux
# 299           Intel Core i7     0   512    Nvidia  Others/No OS/Linux
# 493           AMD Processor  1000     0       AMD  Others/No OS/Linux
# 527           Intel Core i3  2000     0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0     0     Intel                 Mac
#
# [1106 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight       Price  TouchScreen  Ips         PPI  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1  226.983005
#
#        CPU Brand  HDD  SSD GPU Brand   OS
# 0  Intel Core i5    0  128     Intel  Mac

# %% [markdown]
# ## Linear Regression

# %%
# apply columnn transformer on columns company, typename, PPI, SSD, Gpu brand

step1 = ColumnTransformer(transformers=[
    ('col_trf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
], remainder = 'passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('Step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2Score:',r2_score(y_test,y_pred) )
print('Mae:',mean_absolute_error(y_test,y_pred) )
# Out:
# R2Score: 0.7900103845401748
# Mae: 0.21757891217821537

# %% [markdown]
# ## Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7953376158791414
# MAE 0.21941622701626368

# %% [markdown]
# ## Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.788704054372775
# MAE 0.22117273289552097

# %% [markdown]
# ## KNN Regressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7777466972001679
# MAE 0.20947546852781002

# %% [markdown]
# ## Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8268457224881819
# MAE 0.1921017196181772

# %% [markdown]
# ## SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7909021108082668
# MAE 0.213996871078726

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8764529290866718
# MAE 0.16561908839094042

# %% [markdown]
# ## AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7942335238753064
# MAE 0.2306588020685191

# %% [markdown]
# ## Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8709399972598872
# MAE 0.16889204639894984

# %% [markdown]
# ## Exporting the Model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# 5       Acer            Notebook    4    2.10   21312.0000            0    0
# 6      Apple           Ultrabook   16    2.04  114017.6016            0    1
# 7      Apple           Ultrabook    8    1.34   61735.5360            0    0
# 8       Asus           Ultrabook   16    1.30   79653.6000            0    0
# 9       Acer           Ultrabook    8    1.60   41025.6000            0    1
# 10        HP            Notebook    4    1.86   20986.9920            0    0
# 11        HP            Notebook    4    1.86   18381.0672            0    0
# 12     Apple           Ultrabook   16    1.83  130001.6016            0    1
# 13      Dell            Notebook    4    2.20   26581.3920            0    0
# 14     Apple           Ultrabook    8    0.92   67260.6720            0    1
# 15     Apple           Ultrabook    8    1.37   80908.3440            0    1
# 16      Dell            Notebook    8    2.20   39693.6000            0    0
# 17     Apple           Ultrabook   16    1.83  152274.2400            0    1
# 18    Lenovo            Notebook    8    2.20   26586.7200            0    0
# 19      Dell           Ultrabook    8    1.22   52161.1200            1    1
# 20      Asus             Netbook    2    0.98   10224.4320            0    0
# 21    Lenovo              Gaming    8    2.50   53226.7200            0    1
# 22        HP            Notebook    4    1.86   13746.2400            0    0
# 23      Dell  2 in 1 Convertible    8    1.62   43636.3200            1    0
# 24        HP           Ultrabook    8    1.91   35111.5200            0    0
# 25      Dell            Notebook    4    2.30   22305.1392            0    0
# 26     Apple           Ultrabook    8    1.35   58554.7200            0    0
# 27      Dell            Notebook    8    2.20   42624.0000            0    0
# 28      Dell           Ultrabook    8    1.88   69157.4400            0    0
# 29        HP            Notebook    8    2.50   47738.8800            0    0
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1273      HP            Notebook    6    2.19   40705.9200            0    0
# 1274    Asus            Notebook    4    2.20   19660.3200            0    0
# 1275    Asus           Ultrabook    8    1.20   38841.1200            0    1
# 1276    Dell            Notebook    6    2.30   24455.5200            0    0
# 1277    Acer            Notebook    4    2.40   15397.9200            0    0
# 1278    Dell            Notebook    2    2.20   20193.1200            0    0
# 1279  Lenovo            Notebook    8    2.60   47898.7200            0    1
# 1280      HP            Notebook    6    2.04   29303.4672            0    0
# 1281    Dell            Notebook    8    2.30   42943.1472            0    0
# 1282      HP             Netbook    2    1.17   11135.5200            0    0
# 1283    Asus            Notebook    4    2.20   38378.6496            0    0
# 1284  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1285  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1286  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1287      HP            Notebook    6    2.19   40705.9200            0    0
# 1288    Asus            Notebook    4    2.20   19660.3200            0    0
# 1289    Asus           Ultrabook    8    1.20   38841.1200            0    1
# 1290    Dell            Notebook    6    2.30   24455.5200            0    0
# 1291    Acer            Notebook    4    2.40   15397.9200            0    0
# 1292    Dell            Notebook    2    2.20   20193.1200            0    0
# 1293  Lenovo            Notebook    8    2.60   47898.7200            0    1
# 1294      HP            Notebook    6    2.04   29303.4672            0    0
# 1295    Dell            Notebook    8    2.30   42943.1472            0    0
# 1296      HP             Netbook    2    1.17   11135.5200            0    0
# 1297    Asus            Notebook    4    2.20   38378.6496            0    0
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
#              PPI              CPU Brand   HDD  SSD GPU Brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# 5     100.454670          AMD Processor   500    0       AMD
# 6     220.534624          Intel Core i7     0    0     Intel
# 7     127.677940          Intel Core i5     0    0     Intel
# 8     157.350512          Intel Core i7     0  512    Nvidia
# 9     157.350512          Intel Core i5     0  256     Intel
# 10    100.454670          Intel Core i5   500    0     Intel
# 11    141.211998          Intel Core i3   500    0     Intel
# 12    220.534624          Intel Core i7     0  256       AMD
# 13    141.211998          Intel Core i3     0  256       AMD
# 14    226.415547  Other Intel Processor     0  256     Intel
# 15    226.983005          Intel Core i5     0  256     Intel
# 16    141.211998          Intel Core i7     0  256       AMD
# 17    220.534624          Intel Core i7     0  512       AMD
# 18    141.211998          Intel Core i3  1000    0    Nvidia
# 19    165.632118          Intel Core i5     0  128     Intel
# 20    135.094211  Other Intel Processor     0    0     Intel
# 21    141.211998          Intel Core i5  1000  128    Nvidia
# 22    100.454670          AMD Processor   500    0       AMD
# 23    165.632118          Intel Core i5     0  256     Intel
# 24    141.211998          Intel Core i7     0  256     Intel
# 25    100.454670          Intel Core i3  1000    0     Intel
# 26    127.677940          Intel Core i5     0    0     Intel
# 27    141.211998          Intel Core i5     0  256       AMD
# 28    141.211998          Intel Core i7     0  512     Intel
# 29    127.335675          Intel Core i5  1000    0    Nvidia
# ...          ...                    ...   ...  ...       ...
# 1273  100.454670          Intel Core i7  1000    0       AMD
# 1274  100.454670  Other Intel Processor   500    0     Intel
# 1275  165.632118  Other Intel Processor     0  512     Intel
# 1276  100.454670          Intel Core i3  1000    0     Intel
# 1277  100.454670  Other Intel Processor   500    0     Intel
# 1278  100.454670  Other Intel Processor   500    0     Intel
# 1279  141.211998          Intel Core i7  1000    0    Nvidia
# 1280  141.211998          AMD Processor     0    0       AMD
# 1281  100.454670          Intel Core i7  1000    0       AMD
# 1282  135.094211  Other Intel Processor     0    0     Intel
# 1283  100.454670          Intel Core i7   500    0    Nvidia
# 1284  157.350512          Intel Core i7     0  128     Intel
# 1285  276.053530          Intel Core i7     0  512     Intel
# 1286  111.935204  Other Intel Processor     0    0     Intel
# 1287  100.454670          Intel Core i7  1000    0       AMD
# 1288  100.454670  Other Intel Processor   500    0     Intel
# 1289  165.632118  Other Intel Processor     0  512     Intel
# 1290  100.454670          Intel Core i3  1000    0     Intel
# 1291  100.454670  Other Intel Processor   500    0     Intel
# 1292  100.454670  Other Intel Processor   500    0     Intel
# 1293  141.211998          Intel Core i7  1000    0    Nvidia
# 1294  141.211998          AMD Processor     0    0       AMD
# 1295  100.454670          Intel Core i7  1000    0       AMD
# 1296  135.094211  Other Intel Processor     0    0     Intel
# 1297  100.454670          Intel Core i7   500    0    Nvidia
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other Intel Processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other Intel Processor   500    0     Intel
#
#                       OS
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# 5     Others/No OS/Linux
# 6                    Mac
# 7                    Mac
# 8     Others/No OS/Linux
# 9     Others/No OS/Linux
# 10    Others/No OS/Linux
# 11    Others/No OS/Linux
# 12                   Mac
# 13    Others/No OS/Linux
# 14                   Mac
# 15                   Mac
# 16    Others/No OS/Linux
# 17                   Mac
# 18    Others/No OS/Linux
# 19    Others/No OS/Linux
# 20    Others/No OS/Linux
# 21    Others/No OS/Linux
# 22    Others/No OS/Linux
# 23    Others/No OS/Linux
# 24    Others/No OS/Linux
# 25    Others/No OS/Linux
# 26                   Mac
# 27    Others/No OS/Linux
# 28    Others/No OS/Linux
# 29    Others/No OS/Linux
# ...                  ...
# 1273  Others/No OS/Linux
# 1274  Others/No OS/Linux
# 1275  Others/No OS/Linux
# 1276  Others/No OS/Linux
# 1277  Others/No OS/Linux
# 1278  Others/No OS/Linux
# 1279  Others/No OS/Linux
# 1280  Others/No OS/Linux
# 1281  Others/No OS/Linux
# 1282  Others/No OS/Linux
# 1283  Others/No OS/Linux
# 1284  Others/No OS/Linux
# 1285  Others/No OS/Linux
# 1286  Others/No OS/Linux
# 1287  Others/No OS/Linux
# 1288  Others/No OS/Linux
# 1289  Others/No OS/Linux
# 1290  Others/No OS/Linux
# 1291  Others/No OS/Linux
# 1292  Others/No OS/Linux
# 1293  Others/No OS/Linux
# 1294  Others/No OS/Linux
# 1295  Others/No OS/Linux
# 1296  Others/No OS/Linux
# 1297  Others/No OS/Linux
# 1298  Others/No OS/Linux
# 1299  Others/No OS/Linux
# 1300  Others/No OS/Linux
# 1301  Others/No OS/Linux
# 1302  Others/No OS/Linux
#
# [1302 rows x 13 columns]
